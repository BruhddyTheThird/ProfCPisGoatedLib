# %% [markdown]
# # Final Project Exercise (Submit on D2L only)
#
# ### Abhishek Vilekar, Matrim Cirullo-Nesbitt, Andrew Gabaldon
#
# ## Exercise 0, Planning your project (10 points)
#
# **SUBMIT THIS ON D2L only - One submission per group**
#
# Your final project will be a [computational essay](https://arxiv.org/abs/1909.12697) of your own design. My colleague, [Tor Ole Odden](https://www.mn.uio.no/fysikk/english/people/aca/toroo/), and I have borrowed this idea from a proposal by [Stephen Wolfram](https://www.stephenwolfram.com/). In his [original post](https://writings.stephenwolfram.com/2017/11/what-is-a-computational-essay), Wolfram talks about the importance of the computational medium as a way of communicating science.
#
# Tor, myself, and others have started building this idea into a [theory of computational learning in physics](https://journals.aps.org/prper/abstract/10.1103/PhysRevPhysEducRes.15.020152), using computational essays to [argue for the importance of computing in physics](https://www-nature-com.proxy2.cl.msu.edu/articles/s41567-023-02371-2), building [the theory out](https://pubs-aip-org.proxy2.cl.msu.edu/books/monograph/148/chapter/64396056/Physics-Computational-Literacy-What-Why-and-How), and trying to identify the ways making course work and materials to promote [agency, creativity, and ownership](https://onlinelibrary-wiley-com.proxy2.cl.msu.edu/doi/full/10.1002/tea.21821).
#
# **Important Notes:**
# - You can work with a different partner/group for this exercise than your homework group
# - Only one submission per group is required
# - This planning exercise will help guide your final project development
#
# ### Understanding Computational Essays (4 points)
#
# To get started, you should read/skim the following articles; they are not very long:
#
# 1. Wolfram's [What is a Computational Essay?](https://writings.stephenwolfram.com/2017/11/what-is-a-computational-essay)
# 2. Tor and my short paper: [Computational Essays: An Avenue for Scientific Creativity in Physics](https://arxiv.org/abs/1909.12697)
# 3. Wolfram's [Steps to Writing a Computational Essay](https://www.wolframcloud.com/obj/Expositions/Published/ComputationalEssayGuidelines)
#
# **If you are short on time, read Wolfram's original post and the guidelines, and skim/skip the paper by Tor and myself.**
#
# * **1a. (2 pts)** Write a summary of your readings. What did you learn? What was important? What did you find interesting? What questions do you still have? **Full credit will be given for a summary that is at least 200 words long.**
#
# Computational essays are a new way to communicate your science. It might be a good idea to look at some examples. Review the [University of Oslo's Computational Essay Showroom](https://uio-ccse.github.io/computational-essay-showroom).
#
# * **1b. (2 pts)** Find at least one computational essay in the [showroom](https://uio-ccse.github.io/computational-essay-showroom) that you find interesting. Write a summary of the computational essay and evaluate it based on your readings. What did you like? What did you not like? How well does it follow the guidelines for a good computational essay? What are its strengths and weaknesses? **Full credit will be given for a summary that is at least 200 words long.**
#
# ### Planning Your Computational Essay (6 points)
#
# We hear from students that often the hardest part of developing a computational essay is finding a question worth investigating. So we are trying to help you with that. You are not expected to write the computational essay for this midterm. Instead, you are expected to plan it.
#
# Your answers to this question do not commit you to completing this project on the exact idea you present here. You can change your mind later. This is a good exercise to get you thinking about what you might want to do.
#
# For each of the questions below, you should write a paragraph or two (minimum 100 words, maximum 200 words per question) to answer the question. You may include equations, code, or figures in any of your answers.
#
# * **1c. (1 pt)** Who is your team and how are you going to communicate regularly? What is the question(s) you want to investigate? What background information do you need to understand the question(s)? Where can you find that information?
# * **1d. (1 pt)** What is the motivation for the question(s)? Why is it interesting to you? Why is it interesting to others?
# * **1e. (1.5 pts)** What is the computational aspect of the question(s)? What will you calculate? What will you simulate? What will you visualize? Include at least one plot, figure, or image that relates to your topic.
# * **1f. (1.5 pts)** Outline the structure of the setup and analysis that you think you need in order to answer the question(s) you have. What are the key steps you would need to take? What are the key challenges you anticipate?
# * **1g. (1 pt)** How will you know if you have answered the question(s)? What are the key results you would be looking for?
#
# **Alternative Format:** If you prefer, you can write up a single document that answers parts (c) through (g) in a style you prefer. That document should be roughly 400-800 words long and may include equations, code, or figures.
#
# **Submit your answers on D2L through the assignment titled "Midterm 1 Exercise 0".**

# %% [markdown]
# **1a.** We have learned about a new educational technique known as the computational essay. This is an argument presented in writing with code and figures that consolidate your argument. First, you present your motivation or the story you're trying to tell according to Stephen Wolfram in text. Then you write the CodeText which introduces the code you're about to run. The input or the code is also written. Finally, the output of the code is shown to prove your story. It would also be good practice to include background information that your audience may not be aware of just so they understand the purpose behind your essay. These computational essays are usually written in Jupyter notebooks as they combine both code and text. According to Odden and Caballero's paper, Jupyter notebooks have great use for data scientists and professional physicists so it is reasonable to include this tool in the classroom to train future physicists. What I also found interesting is how the computational essay's effectiveness was demonstrated in Odden and Caballero's paper where students enjoyed the creative freedom as the students chose their own approaches to solving the problem they were given. This motivated students and the essay technique was unlike traditional methods of teaching in physics where solutions were either right or wrong. My question is how can the computational essay's effectiveness be quantified and compared to traditional methods? Perhaps we could have a study which controls for traditional methods and compares with computational essay's implementation in the classroom.

# %% [markdown]
# **1b.** A computational essay titled "Simulating a relativistic cyclotron" piqued our interest. It first described the basic principles behind how a cyclotron works, by using a electric field to accelerate particles and a magnetic field to change the particle's direction. The direction of the electric field is switched every half of a lap to continously accelerate the particle. The writer aims to account for relativistic effects when the particle reaches speeds close to the speed of light. By defining the net force, the trajectory of a proton or electron can be integrated and plotted in a x-y plane. By using the relativistic formulas for force, the change in velocity of a proton was observed to decrease as it approached the speed of light. We do like how the writer acknowledge certain limitations in the model of the cyclotron such as production of heat causing friction. However, a plot of the relativistic electron's trajectory should have been plotted in order to compare with the classical prediction. This is because the electron is lighter and so can be accelerated to higher speeds, placing more importance to relativity. Its strengths is that it includes background information. The code is readable and not presented in massive chunks in one cell. They should have focused more on the electron with this essay for reasons already stated. The essay follows the guidelines well. First, introduction and motivation. Then the code and finally the output with explanations supplementing them. Overall, the essay is highly informative and relatively simple to follow.

# %% [markdown]
# **1c.** Our team is Abhishek Vilekar, Andrew Gabaldon, and Matrim Cirullo-Nesbitt. We have and will continue to use GitHub to collaborate and communicate on numerical and writing problems, as well as text messages to directly communicate with each other at a faster pace. We want to investigate, in general, "What other forces (than the magnus effect and drag) influence an object in motion in a fluid like air?" More specifically, for the final, we want to investigate how these forces affect the trajectory of a golf ball in flight. To understand the question, one needs to know how drag hampers a ball's trajectory, and how motion-dependent forces act on an object like a golf ball, like Bernoulli's effect and the Magnus effect. Some of the information can be found on wikipedia or a simple search, but to get a more thorough understanding, there are NASA websites and scientific papers on topics like this.

# %% [markdown]
# **1d.** The motivation for our investigation of aerodynamic forces on a golf ball in flight is two-fold. First, as the person writing this section of the response, I play golf, and have played golf relatively seriously for 5 years now, and answering this question may give me some insights on the mechanics of the my drives. Second, in our investigations into the magnus effect in exercise 1 of this project, we discuss a very similar scenario, the trajectory of a spinning golf ball, taking into account the magnus effect and drag; the results were unsatisfactory in that the maximum height and range of the drive in our scenario did not match empirical data by a significant margin. This could be interesting to an outside audience due to them either being interested in golf, i.e. it might function as another resource to detail swing strategy, or that because it investigates aerodynamic effects that are not commonly modeled in classical situations like these.

# %% [markdown]
# **1e.** The computational aspect of our investigation of aerodynamic forces on a golf ball in flight is that of modeling the accelerations on the ball at each point during flight, given some initial conditions. Also, trying to include the dimples on a golf ball as part of the modeling will require computing not only the real surface area of the golf ball, and computing how the pressure around the ball affects the forces on the ball. This modeling of pressure will likely take the form of computation of some sort of position and velocity dependent field. Importantly, we might need to simulate this, to a simplified degree, as getting this part right will likely be the major difficulty in adding these additional forces. We will definitely visualize the trajectory, for one, as that is our singular goal, but we will also make a concerted effort to simulate the different forces on the ball, so as to see the degree to which the trajectory is affected by each force.
#
# The first image below shows how a ball above a semi-enclosed container can be held in place against gravity due to airflow around it. *obtained from Saint Mary's University.* The second image shows the Navier-Stokes equations for incompressible flow (mach number < 0.5) in vector form. *obtained from Wikipedia.*
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# **1f.** The basic structure and setup should follow something like this:
#  - Intro; talk about what we will be doing in the essay, so explaining the golf ball trajectory model, explaining the real-world application, how models like this are normally calculated, our hypotheses concerning the behavior of the ball, and a basic rundown of our previous iterations of this kind of analysis. This will have the bulk of the low-level background mentioned in 1c.
#  - Theory; talking about what forces exactly we will model, how those forces interact, if they interact, the analytic equations behind them, manipulations on those equations, etc. Also talking more about what we expect from a conceptual mechanics level for the trajectories. This will have the bulk of the high-level background mentioned in 1c.
#  - Methodology; discussing how we take the analytic equations and manipulate them into code, our specific numerical integration techniques for any differential equations we might (will) have, how we find realistic values for numerical integration, how we plan to visualize the results, and how we plan to check our data's significance. This section will have the bulk of code in-essay. We also will detail here a lot of the stumbling blocks we will run into as part of answering the question
#  - Visualization; plots and images, along with captions discussing what each image means and the important parts of each image.
#  - Rationalization and results; discussing the possible answers to the question, given the visualizations and code we create, interpreting the visualizations at a deeper level, coming up with potential reasons for why our model might not be as accurate as hoped - employing the checks discussed in the methodology section, and hypothesizing alternate explanations for our results.
#
# This is probably more than necessary for the question. As for key challenges, we are going to need to do a decent bit of research on the topic of the dynamics of objects in fluid, as well as possibly look into ways to simplify the model without discarding extra forces.

# %% [markdown]
# **1g.** We touched on this in the previous question, on the structure of our essay, but we will likely be trying to find trajectories that are significantly different than the trajectories we have discussed previously. In the same vein, we will be trying to sort of "match" our data to other researchers' data on similar topics, and if ours and theirs are statistically similar, then we think we will have found our answer to the question. Specifically, we are looking for maximum downrange ($x$) values for a ball with $v_i=77$ m/s, $\theta_e\approx10^{\circ}$, to be around 260-280m, and height ($z$) values of about 26-30m.
